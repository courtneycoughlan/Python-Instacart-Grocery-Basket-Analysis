# %% [markdown]
# List of contents:
# 1. Import libraries
# 2. Import data
# 3. Checking data consistency - check output and number of rows and columns of data sets
# 4. Merge data sets into new dataframe
# 5. Export new dataframe as pkl

# %% [markdown]
# 1. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 2. Import data

# %%
# Import order_products_combined pkl
df_orders_products_combined = pd.read_pickle(r'C:\Users\court\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
# Create string of path
path = r'C:\Users\court\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\court\\Instacart Basket Analysis'

# %%
# Import products data
df_products = pd.read_csv(r'C:\Users\court\Instacart Basket Analysis\02 Data\Prepared Data\products_checked.csv', index_col = False)

# %% [markdown]
# 3. Checking data

# %%
# Check shape of pkl file
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %%
# Check shape of products_checked data
df_products.shape
# Out:
# (49672, 6)

# %%
# Check the output of pkl file
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0           0             0   2539329        1    prior             1
# 1           0             0   2539329        1    prior             1
# 2           0             0   2539329        1    prior             1
# 3           0             0   2539329        1    prior             1
# 4           0             0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
# Check the output of products data
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_products_checked = df_products.drop(columns = ['Unnamed: 0'])

# %%
df_products_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = ['Unnamed: 0'])

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = ['Unnamed: 0.1'])

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %% [markdown]
# 4. Merge data

# %%
# Create a new dataframe
df_large_merged_2 = df_orders_products_combined.merge(df_products_checked, on = 'product_id')

# %%
# Confirm results of merge
df_large_merged_2['_merge'].value_counts(dropna=False)
# Out:
# both          32404859
# right_only           0
# left_only            0
# Name: _merge, dtype: int64

# %%
df_products_checked.merge(df_orders_products_combined, on = ['product_id'], how = 'outer')
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies      61.0           19.0
# 1                  1  Chocolate Sandwich Cookies      61.0           19.0
# 2                  1  Chocolate Sandwich Cookies      61.0           19.0
# 3                  1  Chocolate Sandwich Cookies      61.0           19.0
# 4                  1  Chocolate Sandwich Cookies      61.0           19.0
# ...              ...                         ...       ...            ...
# 32435065          69                         NaN       NaN            NaN
# 32435066          69                         NaN       NaN            NaN
# 32435067          69                         NaN       NaN            NaN
# 32435068          69                         NaN       NaN            NaN
# 32435069          69                         NaN       NaN            NaN
#
#           prices   order_id   user_id eval_set  order_number  \
# ...

# %% [markdown]
# 5. Export new dataframe

# %%
# Export data to pkl
df_large_merged_2.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
